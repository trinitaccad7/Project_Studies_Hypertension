# %% [markdown]
# **Fall_2023_Proposal: The data collected and dataframe populated in the previous semester will be further expanded, and the methodology of populating the data frame will be further polished and automated. In addition, the continuation of this project will be collaborated with two more graduate students.**

# %% [markdown]
# <h1><center>Biological Markers Associated with Disease Hypertension and Potential Targets of Antihypertensive Drugs</center></h1>
# <center><h3>Trini Taccad</h3></center>
# <center><h4>Graduate Student in M.S. Bioinformatics Program at NYU Tandon School of Engineering</h4></center>
# <center><h5>Email: tft2013@nyu.edu</h5></center>
# <center><h6>Bioinformatics Guided Studies, Summer 2023</h6></center>

# %%
# Open the populated .csv table named "Progress 3 Data Sheet"

Progress_data_table = pd.read_csv("/Users/trini/OneDrive/Documents/New York University/Guided Studies/Progress 3 Data Sheet.csv")
Progress_data_table

# NOTICE: The cell_location column was empty. Still deciding if I will be including this in my final report
# If decided not to included, this column will be deleted
# Out:
#        Gene                                    Mutation_Remark  \
# 0       ACE  homozygous or compound heterozygous mutation i...
# 1       ACE  homozygous or compound heterozygous mutation i...
# 2       ACE  homozygous or compound heterozygous mutation i...
# 3       ACE  homozygous or compound heterozygous mutation i...
# 4       ACE  homozygous or compound heterozygous mutation i...
# ..      ...                                                ...
# 439  SCNN1B  heterozygous mutation in the SCNN1B gene (6007...
# 440  SCNN1G  heterozygous mutation in the SCNN1G gene (6007...
# 441    WNK1                                autosomal recessive
# 442    WNK4                                autosomal recessive
# 443   SMAD9  heterozygous truncating mutation in the SMAD9 ...
#
#                              System/Pathway_info  \
# 0                       Renin-angiotensin system
# 1                       Renin-angiotensin system
# 2                       Renin-angiotensin system
# ...

# %% [markdown]
# ## <center>Conclusions</center>

# %% [markdown]
# <p style='text-align: justify;'>The purpose of this project report was to obtain and compile data for the biomarkers associated with 'Hypertension'. The pipeline of this report started with data mining through pubmed literatures, then focused more in searching through the ClinVar, OMIM, and KEGG databases in identifying potential gene targets/biomarkers associated with the disease. After identifying all potential genes, the next phase (as shown in the flowchart above) was to search each individual gene in ClinicalTrials.gov in retrieving antihypertensive drugs information. With all of the gathered data in the analysis pipeline, the final task of populating a tab-delimited file with all required data entries was achieved.</p>
#
# <p style='text-align: justify;'>In addition, due to the lack of coding skills and computer science background, there were limitations and inefficiencies in fetching some data entries, which include retrieval of 'mutational remarks', 'drug_class', and 'system/pathway info' that instead of retrieving it by command line execution, the search was perfomed via web browsing the actual KEGG and OMIM databases. Table or tab-delimited entries result from the ClinicalTrials.gov had to be manually searched and downloaded via web browsing, which took many hours to execute. </p>
#
# <p style='text-align: justify;'>As a personal note, the final data output generated here in this project report was constructed and carried out in the best of my current experience, skills and abilities learned after 2 semesters in the Bioinformatics graduate program. The data results obtained in the analysis pipeline could be changed and/or enhanced to increase efficiency and expand data mining and database searching.</p>
